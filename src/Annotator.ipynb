# %%
# Import Libraries
import os
import glob
from PIL import Image
from matplotlib import cbook
from matplotlib import pyplot as plt

# %%
items = os.listdir('/home/afsharino/Desktop/Redeemer-Bot/dataset')
items = [item.split('-')[0] for item in items]
print(f'{len(items)} captchas are annotated now.')

for image in glob.glob('/home/afsharino/Desktop/Redeemer-Bot/downloaded_images/*'):
    image_name = image.split('/')[-1].split('.')[0]
    
    if image.split('/')[-1].split('.')[0] not in items:

        try:
            with Image.open(image) as img:
                plt.imshow(img)
                plt.title(image_name)
                plt.show()

                captcha_number = input("Enter number: ")

                file_name = image.split('/')[-1].split('.')[0] + '-' + captcha_number + '.png'
                file_path = os.path.join('/home/afsharino/Desktop/Redeemer-Bot/dataset', file_name)
                img.save(file_path, 'png')

        except Exception as e:
            print(e)
            print(f"can't import {image.split('/')[-1]}.")

    else:
        continue
# Out:
# 1000 captchas are annotated now.
# Enter number: 0327
# Enter number: 8863
# Enter number: 3670
# Enter number: 9941
# Enter number: 1918
# Enter number: 9285
# Enter number: 9197
# Enter number: 6145
# Enter number: 9629
# Enter number: 0134
# Enter number: 4671
# Enter number: 6652
# Enter number: 8880
# Enter number: 5857
# Enter number: 5801
# Enter number: 9989
# Enter number: 6984
# Enter number: 4952
# Enter number: 0288
# Enter number: 8493
# Enter number: 8009
# Enter number: 6439
# Enter number: 0318
# Enter number: 8981
# Enter number: 8828
# Enter number: 4853
# Enter number: 2408
# Enter number: 0890
# Enter number: 9204
# Enter number: 4087
# Enter number: 9340
# Enter number: 2634
# Enter number: 7693
# Enter number: 8044
# Enter number: 9988
# Enter number: 2935
# Enter number: 6265
# Enter number: 0841
# Enter number: 0639
# Enter number: 8900
# Enter number: 51
# Enter number: 7433
# Enter number: 8707
# Enter number: 2885
# Enter number: 0506
# Enter number: 3612
# Enter number: 6531
# Enter number: 3064
# Enter number: 7117
# Enter number: 0402
# Enter number: 0770
# Enter number: 1025
# Enter number: 7643
# Enter number: 6304
# Enter number: 8985
# Enter number: 1491
# Enter number: 5027
# Enter number: 9773
# Enter number: 8802
# Enter number: 1318
# Enter number: 1845
# Enter number: 2408
# Enter number: 2223
# Enter number: 4291
# Enter number: 9017
# Enter number: 8848
# Enter number: 9221
# Enter number: 8493
# Enter number: 6772
# Enter number: 6384
# Enter number: 6586
# Enter number: 3907
# Enter number: 4437
# Enter number: 0239
# Enter number: 6781
# Enter number: 7771
# Enter number: 6671
# Enter number: 1531
# Enter number: 6751
# Enter number: 1354
# Enter number: 9344
# Enter number: 9057
# Enter number: 2379
